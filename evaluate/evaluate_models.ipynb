# %%
import utils

# %%
utils.evaluate_model('../models/vgg16_model.keras')
# Out:
#                 precision    recall  f1-score   support
#
#          No_DR       0.80      0.99      0.89       351
#           Mild       0.00      0.00      0.00        68
#       Moderate       0.58      0.81      0.68       213
#         Severe       0.00      0.00      0.00        36
# Proliferate_DR       0.00      0.00      0.00        65
#
#       accuracy                           0.71       733
#      macro avg       0.28      0.36      0.31       733
#   weighted avg       0.55      0.71      0.62       733
# C:\Users\adity\Desktop\Code\Python\DiabeticRetinopathy\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
utils.evaluate_model('../models/resnet50_model.keras')
# Out:
#                 precision    recall  f1-score   support
#
#          No_DR       0.88      0.98      0.92       351
#           Mild       0.64      0.24      0.34        68
#       Moderate       0.60      0.88      0.71       213
#         Severe       0.75      0.08      0.15        36
# Proliferate_DR       0.00      0.00      0.00        65
#
#       accuracy                           0.75       733
#      macro avg       0.57      0.44      0.43       733
#   weighted avg       0.69      0.75      0.69       733
# C:\Users\adity\Desktop\Code\Python\DiabeticRetinopathy\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
utils.evaluate_model('../models/efficientnet_model.keras')
# Out:
#                 precision    recall  f1-score   support
#
#          No_DR       0.87      0.98      0.92       351
#           Mild       0.48      0.31      0.38        68
#       Moderate       0.67      0.82      0.73       213
#         Severe       0.67      0.11      0.19        36
# Proliferate_DR       0.42      0.17      0.24        65
#
#       accuracy                           0.76       733
#      macro avg       0.62      0.48      0.49       733
#   weighted avg       0.73      0.76      0.72       733
